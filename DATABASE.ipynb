# %%
import pandas as pd

# %%
df1 = pd.read_csv("andhraRtc.csv")
df2 = pd.read_csv("bihaRstc.csv")
df3 = pd.read_csv("jammuRtc.csv")
df4 = pd.read_csv("keralaRtc.csv")
df5 = pd.read_csv("kadambaRtc.csv")
df6 = pd.read_csv("assamStc.csv")
df7 = pd.read_csv("punjabrtc.csv")
df8 = pd.read_csv("RajasthanRtc.csv")
df9 = pd.read_csv("telunganaRtc.csv")
df10 = pd.read_csv("westbengalStc.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])

# %%
df
# Out:
#                   route_Name  \
# 0    Vijayawada to Hyderabad
# 1    Vijayawada to Hyderabad
# 2    Vijayawada to Hyderabad
# 3    Vijayawada to Hyderabad
# 4    Vijayawada to Hyderabad
# ..                       ...
# 601    Kolkata to Mandarmani
# 602    Kolkata to Mandarmani
# 603    Kolkata to Mandarmani
# 604    Kolkata to Mandarmani
# 605    Kolkata to Mandarmani
#
#                                             route_Link  \
# 0    https://www.redbus.in/bus-tickets/vijayawada-t...
# 1    https://www.redbus.in/bus-tickets/vijayawada-t...
# 2    https://www.redbus.in/bus-tickets/vijayawada-t...
# 3    https://www.redbus.in/bus-tickets/vijayawada-t...
# 4    https://www.redbus.in/bus-tickets/vijayawada-t...
# ..                                                 ...
# 601  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 602  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 603  https://www.redbus.in/bus-tickets/kolkata-to-m...
# ...

# %%
df.to_csv('bus_routes.csv', index = False)

# %%
df = pd.read_csv('bus_routes.csv')

# %%
df
# Out:
#                    route_Name  \
# 0     Vijayawada to Hyderabad
# 1     Vijayawada to Hyderabad
# 2     Vijayawada to Hyderabad
# 3     Vijayawada to Hyderabad
# 4     Vijayawada to Hyderabad
# ...                       ...
# 6882    Kolkata to Mandarmani
# 6883    Kolkata to Mandarmani
# 6884    Kolkata to Mandarmani
# 6885    Kolkata to Mandarmani
# 6886    Kolkata to Mandarmani
#
#                                              route_Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 6882  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6883  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6884  https://www.redbus.in/bus-tickets/kolkata-to-m...
# ...

# %%
df = df.drop('id', axis=1)

# %%
df
# Out:
#                    route_Name  \
# 0     Vijayawada to Hyderabad
# 1     Vijayawada to Hyderabad
# 2     Vijayawada to Hyderabad
# 3     Vijayawada to Hyderabad
# 4     Vijayawada to Hyderabad
# ...                       ...
# 6882    Kolkata to Mandarmani
# 6883    Kolkata to Mandarmani
# 6884    Kolkata to Mandarmani
# 6885    Kolkata to Mandarmani
# 6886    Kolkata to Mandarmani
#
#                                              route_Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 6882  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6883  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6884  https://www.redbus.in/bus-tickets/kolkata-to-m...
# ...

# %%
df.to_csv('Bus_Routes.csv', index = False)

# %%
df = pd.read_csv('Bus_Routes.csv')

# %%
df
# Out:
#                    route_Name  \
# 0     Vijayawada to Hyderabad
# 1     Vijayawada to Hyderabad
# 2     Vijayawada to Hyderabad
# 3     Vijayawada to Hyderabad
# 4     Vijayawada to Hyderabad
# ...                       ...
# 6882    Kolkata to Mandarmani
# 6883    Kolkata to Mandarmani
# 6884    Kolkata to Mandarmani
# 6885    Kolkata to Mandarmani
# 6886    Kolkata to Mandarmani
#
#                                              route_Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 6882  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6883  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6884  https://www.redbus.in/bus-tickets/kolkata-to-m...
# ...

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv("Bus_Routes.csv")

# Add a new 'id' column with default values (e.g., incrementing numbers)
df.insert(0, 'id', range(1, len(df) + 1))

# Rename columns with the new 'id' column included
df.columns = ['id', 'route_Name', 'route_Link', 'bus_Name', 'bus_types', 'departing',
              'duration', 'arrival', 'rating', 'price', 'seats']

# Print DataFrame to verify the new column names
print("\nAfter renaming and adding 'id':")
print(df.head())
print(df.columns)

# Save the DataFrame with the new column names to a new CSV file (optional)
df.to_csv('BusRoutes.csv',index=False)
# Out:
# After renaming and adding 'id':
#    id               route_Name  \
# 0   1  Vijayawada to Hyderabad
# 1   2  Vijayawada to Hyderabad
# 2   3  Vijayawada to Hyderabad
# 3   4  Vijayawada to Hyderabad
# 4   5  Vijayawada to Hyderabad
#
#                                           route_Link            bus_Name  \
# 0  https://www.redbus.in/bus-tickets/vijayawada-t...   ('TSRTC', '1582')
# 1  https://www.redbus.in/bus-tickets/vijayawada-t...  ('TSRTC', '40162')
# 2  https://www.redbus.in/bus-tickets/vijayawada-t...   ('TSRTC', '1468')
# 3  https://www.redbus.in/bus-tickets/vijayawada-t...   ('TSRTC', '9945')
# 4  https://www.redbus.in/bus-tickets/vijayawada-t...   ('TSRTC', '1547')
#
#                                    bus_types departing duration arrival  \
# 0               RAJDHANI (A.C. Semi Sleeper)     12:10  07h 00m   16:00
# 1  GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)     12:20  07h 00m   16:25
# 2                                    eGARUDA     12:40  07h 00m   16:30
# ...

# %%
df
# Out:
#         id               route_Name  \
# 0        1  Vijayawada to Hyderabad
# 1        2  Vijayawada to Hyderabad
# 2        3  Vijayawada to Hyderabad
# 3        4  Vijayawada to Hyderabad
# 4        5  Vijayawada to Hyderabad
# ...    ...                      ...
# 6882  6883    Kolkata to Mandarmani
# 6883  6884    Kolkata to Mandarmani
# 6884  6885    Kolkata to Mandarmani
# 6885  6886    Kolkata to Mandarmani
# 6886  6887    Kolkata to Mandarmani
#
#                                              route_Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 6882  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6883  https://www.redbus.in/bus-tickets/kolkata-to-m...
# ...

# %%
df.isna().sum()
# Out:
# id            0
# route_Name    0
# route_Link    0
# bus_Name      0
# bus_types     0
# departing     0
# duration      0
# arrival       0
# rating        0
# price         0
# seats         0
# dtype: int64

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost",user="root",password="Reethikasql11",database="bus_routes")
cursor = conn.cursor()

# %%
create = """CREATE TABLE buses (
    id INT AUTO_INCREMENT PRIMARY KEY,
    route_name TEXT,
    route_link TEXT,
    bus_name TEXT,
    bus_types TEXT,
    departing TIME,
    duration TEXT,
    arrival TIME,
    rating FLOAT,
    price TEXT,
    seats TEXT
)"""

# %%
cursor.execute(create)
conn.commit()

# %%
insert = """insert into  buses(id, route_Name, route_Link, bus_Name, bus_types, departing,
       duration, arrival, rating, price, seats) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

# %%
from tqdm import tqdm

for index, row in tqdm (df.iterrows()):
    cursor.execute(insert, (row["id"],row["route_Name"], row["route_Link"], row["bus_Name"], row["bus_types"],row["departing"],row["duration"],row["arrival"],row["rating"],row["price"],row["seats"]))
    conn.commit()
# Out:
# 6887it [00:36, 190.21it/s]
